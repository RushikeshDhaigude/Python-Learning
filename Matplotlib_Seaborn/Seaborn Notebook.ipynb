# %% [markdown]
# # Seaborn Tutorial

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Shree\Desktop\ANALYTICS VIDYA\PYTHON\class\titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Violin Plot

# %%
sns.violinplot(x = 'Sex', y = 'Age', data = df)  #bivariate
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.violinplot(x="Sex",y="Age",hue="Survived",data=df)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.violinplot(x = 'Sex', y = 'Age', hue = 'Survived', data = df, split = True) #Multivariate
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ## Pairplot

# %%
iris=pd.read_csv(r"C:\Users\Shree\Desktop\ANALYTICS VIDYA\PYTHON\class\Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.drop("Id",axis=1,inplace=True)
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris,hue="Species")

# %% [markdown]
# ## Distplot

# %%
sns.distplot(iris['SepalLengthCm'])
# Out:
# C:\Users\Shree\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Density'>

# %%
sns.distplot(df['Fare'])
# Out:
# C:\Users\Shree\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
sns.distplot(df['Fare'], hist = False)
# Out:
# C:\Users\Shree\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
sns.distplot(df['Fare'], kde = False)
# Out:
# C:\Users\Shree\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare'>

# %%
sns.displot(df["Age"],kind="hist",kde=False)

# %%
sns.displot(df["Age"],kind="hist",kde=True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## CountPlot

# %%
df['Embarked'].value_counts()['S']
# Out:
# 644

# %%
sns.countplot(df['Embarked'])

plt.text(x = 0.01,y = df['Embarked'].value_counts()['S'] + 5, s=str(df['Embarked'].value_counts()['S']))
plt.text(x = 1,y = df['Embarked'].value_counts()['C'] + 5, s=str(df['Embarked'].value_counts()['C']))
plt.text(x = 2,y = df['Embarked'].value_counts()['Q'] + 5, s=str(df['Embarked'].value_counts()['Q']))
# Out:
# C:\Users\Shree\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(2, 82, '77')

# %% [markdown]
# ## Regplot

# %%
sns.regplot(x = 'SepalLengthCm' , y = 'PetalLengthCm', data = iris)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.regplot(x="SepalLengthCm",y="SepalLengthCm",data=iris)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalLengthCm'>

# %% [markdown]
# ## Heatmap

# %%
iris.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.heatmap(iris.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(iris.corr(),annot=True,cmap="Blues")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(df['Age'])    #Univariate
# Out:
# C:\Users\Shree\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x = df['Sex'], y = df['Age'] )    #Bivariate
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x = df['Sex'], y = df['Age'], hue = df['Survived'] )    #Multi-variate
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %%
heart=pd.read_csv(r"C:\Users\Shree\Desktop\ANALYTICS VIDYA\PYTHON\class\Heart_disease.csv")
heart.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    CVD
# 0    0
# 1    0
# 2    0
# 3    1
# 4    0

# %%
heart['male'] = heart['male'].astype('category')
heart['education'] = heart['education'].astype('category')
heart['currentSmoker'] = heart['currentSmoker'].astype('category')
heart['BPMeds'] = heart['BPMeds'].astype('category')
heart['prevalentStroke'] = heart['prevalentStroke'].astype('category')
heart['prevalentHyp'] = heart['prevalentHyp'].astype('category')
heart['diabetes'] = heart['diabetes'].astype('category')
heart['CVD'] = heart['CVD'].astype('category')

# %%
sns.violinplot(x = 'male', y = 'age', data = heart)  #bivariate
# Out:
# <AxesSubplot:xlabel='male', ylabel='age'>

# %%
sns.violinplot(x = 'male', y = 'age',hue="diabetes" ,data = heart,split=True)  #bivariate
# Out:
# <AxesSubplot:xlabel='male', ylabel='age'>

# %%
sns.violinplot(x = heart['diabetes'], y = heart['age'], hue = heart['CVD'], split = True)
# Out:
# <AxesSubplot:xlabel='diabetes', ylabel='age'>

# %%
sns.pairplot(heart,hue="male")

# %%
sns.distplot(heart["BMI"], kde = True)
# Out:
# C:\Users\Shree\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='BMI', ylabel='Density'>

# %%
heart.head()
# Out:
#   male  age education currentSmoker  cigsPerDay BPMeds prevalentStroke  \
# 0    1   39       4.0             0         0.0    0.0               0
# 1    0   46       2.0             0         0.0    0.0               0
# 2    1   48       1.0             1        20.0    0.0               0
# 3    0   61       3.0             1        30.0    0.0               0
# 4    0   46       3.0             1        23.0    0.0               0
#
#   prevalentHyp diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose CVD
# 0            0        0    195.0  106.0   70.0  26.97       80.0     77.0   0
# 1            0        0    250.0  121.0   81.0  28.73       95.0     76.0   0
# 2            0        0    245.0  127.5   80.0  25.34       75.0     70.0   0
# 3            1        0    225.0  150.0   95.0  28.58       65.0    103.0   1
# 4            0        0    285.0  130.0   84.0  23.10       85.0     85.0   0

# %%
sns.distplot(heart['totChol'])
# Out:
# C:\Users\Shree\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='totChol', ylabel='Density'>

# %%
sns.countplot(heart['education'])
# Out:
# C:\Users\Shree\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
sns.heatmap(heart.corr() , annot = True)
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x=heart['education'],y=heart["heartRate"],hue=heart["diabetes"])    #Univariate
# Out:
# <AxesSubplot:xlabel='education', ylabel='heartRate'>
